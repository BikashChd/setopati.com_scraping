# %%
from bs4 import BeautifulSoup
import requests
n = int(input("Enter page no = "))
all_news_link = []
for i in range(n):
  news_link = []
  url = BeautifulSoup(f'https://www.setopati.com/politics?page={i}', 'html.parser')
  soup = requests.get(url)
  soup = soup.text
  codes = BeautifulSoup(soup, "lxml")
  codes.find_all("section", class_="section special-news cat-list")
  for link in codes.find_all('a'):
      news_link.append(link.get('href'))

  all_news_link += news_link[19:-23]

all_news_link
# Out:
# /usr/lib/python3/dist-packages/bs4/__init__.py:431: MarkupResemblesLocatorWarning: "https://www.setopati.com/politics?page=0" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /usr/lib/python3/dist-packages/bs4/__init__.py:431: MarkupResemblesLocatorWarning: "https://www.setopati.com/politics?page=1" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /usr/lib/python3/dist-packages/bs4/__init__.py:431: MarkupResemblesLocatorWarning: "https://www.setopati.com/politics?page=2" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# ['https://www.setopati.com/literature',
#  'https://www.setopati.com/ghumphir',
#  'https://www.setopati.com/global',
#  'javascript:void(0)',
#  'https://tvsnepal.com/offer/raider-ride-with-pride',
#  'https://tvsnepal.com/offer/raider-ride-with-pride',
#  'https://www.setopati.com/politics/278208',
#  'https://www.setopati.com/politics/278208',
#  'https://www.setopati.com/politics/278264',
#  'https://www.setopati.com/politics/278262',
#  'https://www.setopati.com/politics/278259',
#  'https://www.setopati.com/politics/278257',
#  'https://www.setopati.com/politics/278256',
#  'https://www.setopati.com/politics/278254',
#  'https://www.setopati.com/politics/278251',
#  'https://www.setopati.com/politics/278237',
#  'https://www.setopati.com/politics/278229',
#  'https://www.setopati.com/politics/278228',
#  'https://www.setopati.com/politics/278226',
#  'https://www.setopati.com/politics/278227',
#  'https://www.setopati.com/politics/278212',
#  'https://www.setopati.com/politics/278211',
#  'https://www.setopati.com/politics/278202',
#  'https://www.setopati.com/politics/278197',
#  'https://www.setopati.com/politics/277829',
#  'https://www.setopati.com/politics/278195',
#  'https://www.setopati.com/politics/278194',
#  'https://www.setopati.com/politics/278188',
#  'https://www.setopati.com/politics/278192',
#  'https://www.setopati.com/politics/278183',
#  'https://www.setopati.com/politics/278182',
#  'https://www.setopati.com/politics/278178',
#  'https://www.setopati.com/politics/278174',
#  'https://www.setopati.com/politics/278173',
#  'https://www.setopati.com/politics/278169',
#  'https://www.setopati.com/politics/278166',
#  'https://www.setopati.com/politics/278165',
#  'https://www.setopati.com/politics/278162',
#  'https://www.setopati.com/politics?page=2',
#  'https://www.setopati.com/politics?page=3',
#  'https://www.setopati.com/politics?page=4',
#  'https://www.setopati.com/politics?page=5',
#  'https://www.setopati.com/politics?page=2',
#  'https://www.setopati.com/',
#  'https://www.facebook.com/setopati/',
#  'https://twitter.com/setopati',
#  'https://www.youtube.com/user/setopati',
#  'https://www.setopati.com/literature',
#  'https://www.setopati.com/ghumphir',
#  'https://www.setopati.com/global',
#  'javascript:void(0)',
#  'https://tvsnepal.com/offer/raider-ride-with-pride',
#  'https://tvsnepal.com/offer/raider-ride-with-pride',
#  'https://www.setopati.com/politics/278208',
#  'https://www.setopati.com/politics/278208',
#  'https://www.setopati.com/politics/278264',
#  'https://www.setopati.com/politics/278262',
#  'https://www.setopati.com/politics/278259',
#  'https://www.setopati.com/politics/278257',
#  'https://www.setopati.com/politics/278256',
#  'https://www.setopati.com/politics/278254',
#  'https://www.setopati.com/politics/278251',
#  'https://www.setopati.com/politics/278237',
#  'https://www.setopati.com/politics/278229',
#  'https://www.setopati.com/politics/278228',
#  'https://www.setopati.com/politics/278226',
#  'https://www.setopati.com/politics/278227',
#  'https://www.setopati.com/politics/278212',
#  'https://www.setopati.com/politics/278211',
#  'https://www.setopati.com/politics/278202',
#  'https://www.setopati.com/politics/278197',
#  'https://www.setopati.com/politics/277829',
#  'https://www.setopati.com/politics/278195',
#  'https://www.setopati.com/politics/278194',
#  'https://www.setopati.com/politics/278188',
#  'https://www.setopati.com/politics/278192',
#  'https://www.setopati.com/politics/278183',
#  'https://www.setopati.com/politics/278182',
#  'https://www.setopati.com/politics/278178',
#  'https://www.setopati.com/politics/278174',
#  'https://www.setopati.com/politics/278173',
#  'https://www.setopati.com/politics/278169',
#  'https://www.setopati.com/politics/278166',
#  'https://www.setopati.com/politics/278165',
#  'https://www.setopati.com/politics/278162',
#  'https://www.setopati.com/politics?page=2',
#  'https://www.setopati.com/politics?page=3',
#  'https://www.setopati.com/politics?page=4',
#  'https://www.setopati.com/politics?page=5',
#  'https://www.setopati.com/politics?page=2',
#  'https://www.setopati.com/',
#  'https://www.facebook.com/setopati/',
#  'https://twitter.com/setopati',
#  'https://www.youtube.com/user/setopati',
#  'https://www.setopati.com/literature',
#  'https://www.setopati.com/ghumphir',
#  'https://www.setopati.com/global',
#  'javascript:void(0)',
#  'https://tvsnepal.com/offer/raider-ride-with-pride',
#  'https://tvsnepal.com/offer/raider-ride-with-pride',
#  'https://www.setopati.com/politics/278208',
#  'https://www.setopati.com/politics/278208',
#  'https://www.setopati.com/politics/278161',
#  'https://www.setopati.com/politics/278159',
#  'https://www.setopati.com/politics/278158',
#  'https://www.setopati.com/politics/278155',
#  'https://www.setopati.com/politics/278147',
#  'https://www.setopati.com/politics/278142',
#  'https://www.setopati.com/politics/278137',
#  'https://www.setopati.com/politics/278129',
#  'https://www.setopati.com/politics/278126',
#  'https://www.setopati.com/politics/278122',
#  'https://www.setopati.com/politics/278121',
#  'https://www.setopati.com/politics/278119',
#  'https://www.setopati.com/politics/278117',
#  'https://www.setopati.com/politics/278107',
#  'https://www.setopati.com/politics/278116',
#  'https://www.setopati.com/politics/278114',
#  'https://www.setopati.com/politics/278110',
#  'https://www.setopati.com/politics/278108',
#  'https://www.setopati.com/politics/278101',
#  'https://www.setopati.com/politics/278098',
#  'https://www.setopati.com/politics/278097',
#  'https://www.setopati.com/politics/278096',
#  'https://www.setopati.com/politics/278091',
#  'https://www.setopati.com/politics/278087',
#  'https://www.setopati.com/politics/278085',
#  'https://www.setopati.com/politics/278084',
#  'https://www.setopati.com/politics/278083',
#  'https://www.setopati.com/politics/278077',
#  'https://www.setopati.com/politics/278073',
#  'https://www.setopati.com/politics/278047',
#  'https://www.setopati.com/politics?page=1',
#  'https://www.setopati.com/politics?page=1',
#  'https://www.setopati.com/politics?page=3',
#  'https://www.setopati.com/politics?page=4',
#  'https://www.setopati.com/politics?page=5',
#  'https://www.setopati.com/politics?page=3',
#  'https://www.setopati.com/',
#  'https://www.facebook.com/setopati/',
#  'https://twitter.com/setopati',
#  'https://www.youtube.com/user/setopati']

# %%
all_news = {'news':[],'category':['politics']*len(all_news_link)}
for link in all_news_link:
  try:
    url = BeautifulSoup(link, 'html.parser')
    soup = requests.get(url)
    soup = soup.text
    codes = BeautifulSoup(soup, "lxml")
    news = codes.find("div", class_="editor-box").text
    all_news['news'].append(news)
  except:
    continue
# Out:
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277963" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277971" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277968" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277960" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277959" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277953" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277946" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277942" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277941" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277938" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277934" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277919" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277918" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277915" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277905" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277911" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277912" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277910" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277906" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277903" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277902" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277901" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277900" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277899" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277892" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277890" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277887" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277886" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277880" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277869" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.7/dist-packages/bs4/__init__.py:336: UserWarning: "https://www.setopati.com/politics/277860" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup

# %%
import pandas as pd
df = pd.DataFrame(all_news)
df
# Out:
#                                                  news  category
# 0   \nपूर्व अर्थमन्त्री जनार्दन शर्मामाथि छानबिनका...  politics
# 1   \nपूर्व अर्थमन्त्री जनार्दन शर्मामाथि छानबिनका...  politics
# 2   \nनुवाकोटको बेलकोटगढी नगरपालिका–१२ का निर्वाचि...  politics
# 3   \nगत वैशाखमा भएको स्थानीय तहको निर्वाचनमा ४१ द...  politics
# 4   \nपोखरा महानगरले देशका ६ वटै महानगरका मेयरहरूक...  politics
# 5   \nपूर्वअर्थमन्त्री जनार्दन शर्मामाथि छानबिन गर...  politics
# 6   \nपूर्वअर्थमन्त्री जनार्दन शर्मामाथि छानबिन गर...  politics
# 7   \nसरकारले सबैको लागि दिगो खानेपानी तथा सरसफाई ...  politics
# 8   \nनेपाली कांग्रेसका नेता प्रदीप गिरि अस्पताल भ...  politics
# 9   \nआगामी मंसिर ४ गते संघीय संसदको चुनाव हुनसक्न...  politics
# 10  \nप्रतिनिधिसभाको आजको बैठकमा राष्ट्रियसभामा उत...  politics
# 11  \nपूर्वअर्थमन्त्री जनार्दन शर्मामाथि छानबिन गर...  politics
# 12  \nस्थानीय तहको चुनावी इतिहासमै पहिलो पटक झापाक...  politics
# 13  \nनेपाल प्रहरी र सशस्त्र प्रहरीको बढुवामा परिव...  politics
# 14  \nसभामुख अग्निप्रसाद सापकोटाले सांसदहरूलाई मास...  politics
# 15  \nउद्योग वाणिज्य तथा आपूर्तिमन्त्री दीलेन्द्रप...  politics
# 16  \nनेपाली कांग्रेसका नेता शेखर कोइराला हिजोआज म...  politics
# 17  \nप्रदेश १ सरकारले राजश्व अध्ययन कार्यदल गठन ग...  politics
# 18  \nनेकपा एमालेका सांसद योगेशकुमार भट्टराईले स्व...  politics
# 19  \nराष्ट्रपति विद्यादेवी भण्डारीले रूसी महासंघ,...  politics
# 20  \nकंग्रेस आईका नेता राहुल गान्धीलाई दिल्ली प्र...  politics
# 21  \nनेकपा (माओवादी केन्द्र) को पदाधिकारी चयन मंस...  politics
# 22  \nस्थानीय तहमा चुनिएका नवनिर्वाचित पदाधिकारीले...  politics
# 23  \nनेकपा (माओवादी केन्द्र) का अध्यक्ष पुष्पकमल ...  politics
# 24  \nअर्थ मन्त्रालयले डिलिट भएको दाबी गरेको सिसिट...  politics
# 25  \nअहिले नेकपा माओवादी केन्द्र, नेकपा (एकीकृत स...  politics
# 26  \nरमित ढुंगानाको निर्देशनमा बन्न लागेको फिल्म ...  politics
# 27  \nबजेट निर्माणमा तत्कालीन अर्थमन्त्री जनार्दन ...  politics
# 28  \nबजेट निर्माणमा अनधिकृत व्यक्तिको संलग्नता रह...  politics
# 29  \nपूर्वप्रधानमन्त्री बाबुराम भट्टराईले नेपाल स...  politics
# 30  \nनेकपा एमाले नेता घनश्याम भुसालले माओवादी केन...  politics
# 31  \nराष्ट्रिय युवा परिषदका कार्यकारी उपाध्यक्ष स...  politics
